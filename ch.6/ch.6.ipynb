# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # 0. Data
#
# Source & Description: https://archive.ics.uci.edu/dataset/468/online+shoppers+purchasing+intention+dataset

# %%
df = pd.read_csv("./data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12330 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12330 non-null  int64
#  1   Administrative_Duration  12330 non-null  float64
#  2   Informational            12330 non-null  int64
#  3   Informational_Duration   12330 non-null  float64
#  4   ProductRelated           12330 non-null  int64
#  5   ProductRelated_Duration  12330 non-null  float64
#  6   BounceRates              12330 non-null  float64
#  7   ExitRates                12330 non-null  float64
#  8   PageValues               12330 non-null  float64
#  9   SpecialDay               12330 non-null  float64
#  10  Month                    12330 non-null  object
#  11  OperatingSystems         12330 non-null  int64
#  12  Browser                  12330 non-null  int64
#  13  Region                   12330 non-null  int64
#  14  TrafficType              12330 non-null  int64
#  15  VisitorType              12330 non-null  object
#  16  Weekend                  12330 non-null  bool
#  17  Revenue                  12330 non-null  bool
# dtypes: bool(2), float64(7), int64(7), object(2)
# memory usage: 1.5+ MB

# %%
df.tail()
# Out:
#        Administrative  Administrative_Duration  Informational  \
# 12325               3                    145.0              0
# 12326               0                      0.0              0
# 12327               0                      0.0              0
# 12328               4                     75.0              0
# 12329               0                      0.0              0
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 12325                     0.0              53              1783.791667
# 12326                     0.0               5               465.750000
# 12327                     0.0               6               184.250000
# 12328                     0.0              15               346.000000
# 12329                     0.0               3                21.250000
#
#        BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 12325     0.007143   0.029031   12.241717         0.0   Dec                 4
# 12326     0.000000   0.021333    0.000000         0.0   Nov                 3
# 12327     0.083333   0.086667    0.000000         0.0   Nov                 3
# 12328     0.000000   0.021053    0.000000         0.0   Nov                 2
# 12329     0.000000   0.066667    0.000000         0.0   Nov                 3
#
#        Browser  Region  TrafficType        VisitorType  Weekend  Revenue
# 12325        6       1            1  Returning_Visitor     True    False
# 12326        2       1            8  Returning_Visitor     True    False
# 12327        2       1           13  Returning_Visitor     True    False
# 12328        2       3           11  Returning_Visitor    False    False
# 12329        2       1            2        New_Visitor     True    False

# %% [markdown]
# # 1. Encoding

# %% [markdown]
# ## Month Encoding

# %%
from time import strptime

# %%
df["MonthNum"] = df["Month"].apply(lambda x: strptime(x[:3],'%b').tm_mon)

# %%
df["MonthNum"].unique()
# Out:
# array([ 2,  3,  5, 10,  6,  7,  8, 11,  9, 12])

# %% [markdown]
# ## Visitor Type Encoding

# %%
df["VisitorType"].unique()
# Out:
# array(['Returning_Visitor', 'New_Visitor', 'Other'], dtype=object)

# %%
df["VisitorTypeNum"] = df["VisitorType"].apply(lambda x: 0 if x == "New_Visitor" else 1 if x == "Returning_Visitor" else 2)

# %%
df["VisitorTypeNum"].unique()
# Out:
# array([1, 0, 2])

# %% [markdown]
# ## Weekend Encoding

# %%
df["Weekend"].unique()
# Out:
# array([False,  True])

# %%
df["Weekend"] = df["Weekend"].astype(int)

# %%
df["Weekend"].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ## Revenue Encoding

# %%
df["Revenue"].unique()
# Out:
# array([False,  True])

# %%
df["Revenue"] = df["Revenue"].astype(int)

# %%
df["Revenue"].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ## Results

# %%
df.describe()
# Out:
#        Administrative  Administrative_Duration  Informational  \
# count    12330.000000             12330.000000   12330.000000
# mean         2.315166                80.818611       0.503569
# std          3.321784               176.779107       1.270156
# min          0.000000                 0.000000       0.000000
# 25%          0.000000                 0.000000       0.000000
# 50%          1.000000                 7.500000       0.000000
# 75%          4.000000                93.256250       0.000000
# max         27.000000              3398.750000      24.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# count            12330.000000    12330.000000             12330.000000
# mean                34.472398       31.731468              1194.746220
# std                140.749294       44.475503              1913.669288
# min                  0.000000        0.000000                 0.000000
# 25%                  0.000000        7.000000               184.137500
# 50%                  0.000000       18.000000               598.936905
# 75%                  0.000000       38.000000              1464.157214
# max               2549.375000      705.000000             63973.522230
#
#         BounceRates     ExitRates    PageValues    SpecialDay  \
# count  12330.000000  12330.000000  12330.000000  12330.000000
# mean       0.022191      0.043073      5.889258      0.061427
# std        0.048488      0.048597     18.568437      0.198917
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.014286      0.000000      0.000000
# 50%        0.003112      0.025156      0.000000      0.000000
# 75%        0.016813      0.050000      0.000000      0.000000
# max        0.200000      0.200000    361.763742      1.000000
#
#        OperatingSystems       Browser        Region   TrafficType  \
# count      12330.000000  12330.000000  12330.000000  12330.000000
# mean           2.124006      2.357097      3.147364      4.069586
# std            0.911325      1.717277      2.401591      4.025169
# min            1.000000      1.000000      1.000000      1.000000
# 25%            2.000000      2.000000      1.000000      2.000000
# 50%            2.000000      2.000000      3.000000      2.000000
# 75%            3.000000      2.000000      4.000000      4.000000
# max            8.000000     13.000000      9.000000     20.000000
#
#             Weekend       Revenue      MonthNum  VisitorTypeNum
# count  12330.000000  12330.000000  12330.000000    12330.000000
# mean       0.232603      0.154745      7.651987        0.869505
# std        0.422509      0.361676      3.392841        0.356740
# min        0.000000      0.000000      2.000000        0.000000
# 25%        0.000000      0.000000      5.000000        1.000000
# 50%        0.000000      0.000000      7.000000        1.000000
# 75%        0.000000      0.000000     11.000000        1.000000
# max        1.000000      1.000000     12.000000        2.000000

# %% [markdown]
# # 2. Target & Features

# %%
TARGET = "Revenue"
FEATURES = [
    'Administrative',
    'Administrative_Duration',
    'BounceRates',
    'Browser',
    'ExitRates',
    'Informational',
    'Informational_Duration',
    'MonthNum',
    'OperatingSystems',
    'PageValues',
    'ProductRelated',
    'ProductRelated_Duration',
    'Region',
    'SpecialDay',
    'TrafficType',
    'VisitorTypeNum',
    'Weekend'
]

# %%
X = df[FEATURES]
Y = df[TARGET]

# %%
X.shape, Y.shape
# Out:
# ((12330, 17), (12330,))

# %% [markdown]
# # 3. Tree-Based Modeling

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn import metrics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_x, test_x, train_y, test_y= train_test_split(X, Y, test_size=0.2, random_state=1234)

# %%
train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((9864, 17), (2466, 17), (9864,), (2466,))

# %%
train_y.mean(), test_y.mean()
# Out:
# (0.15450121654501217, 0.15571776155717762)

# %%
def eval_func(actual, pred, pred_proba):
    # Accuracy & Precision & Recall
    accuracy = (actual == pred).mean()
    precision = metrics.precision_score(actual, pred)
    recall = metrics.recall_score(actual, pred)
    print("** Key Metrics:")
    print(f"Accuracy: {accuracy*100:.1f}%, Precision: {precision*100:.01f}%, Recall: {recall*100:.01f}%")
    # AUC/ROC
    print("\n\n** AUC/ROC:")
    dp = metrics.RocCurveDisplay.from_predictions(
        actual,
        pred_proba,
        name="Conversion",
        color="darkorange",
    )
    _ = dp.ax_.set(
        xlabel="False Positive Rate",
        ylabel="True Positive Rate",
        title="ROC Curve",
    )
    plt.grid()
    plt.show()
    # Confusion Matrix
    print("\n\n** Confusion Matrix:")
    cf_matrix = metrics.confusion_matrix(actual, pred)
    
    ax = plt.subplot()
    sns.heatmap(
        cf_matrix, 
        annot=True, 
        annot_kws={"size": 10},
        fmt="g", 
        ax=ax
    )

    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")
    ax.set_title(f"Confusion Matrix")
    plt.show()
    
    ax = plt.subplot()
    sns.heatmap(
        cf_matrix/cf_matrix.sum(axis=0), 
        annot=True, 
        annot_kws={"size": 10},
        fmt=".1%", 
        cmap='Blues',
        ax=ax
    )

    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")
    ax.set_title(f"Confusion Matrix - Prediction Precision")
    plt.show()
    
    ax = plt.subplot()
    sns.heatmap(
        cf_matrix/cf_matrix.sum(axis=1)[...,None], 
        annot=True, 
        annot_kws={"size": 10},
        fmt=".1%", 
        cmap='Blues',
        ax=ax
    )

    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")
    ax.set_title(f"Confusion Matrix - Prediction Recall")
    plt.show()

# %% [markdown]
# ## 3.1. RandomForest

# %% [markdown]
# ### 3.1.1. Train

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(
    n_estimators=250, max_depth=5, class_weight="balanced", n_jobs=-1
)

# %%
# %%time

rf_model.fit(train_x, train_y)
# Out:
# CPU times: user 1.48 s, sys: 194 ms, total: 1.68 s
# Wall time: 469 ms
# RandomForestClassifier(class_weight='balanced', max_depth=5, n_estimators=250,
#                        n_jobs=-1)

# %% [markdown]
# ### 3.1.2. Eval

# %%
rf_pred = rf_model.predict(test_x)

# %%
rf_pred_proba = rf_model.predict_proba(test_x)[:,1]

# %%
eval_func(test_y, rf_pred, rf_pred_proba)
# Out:
# ** Key Metrics:
# Accuracy: 86.3%, Precision: 53.8%, Recall: 84.1%
#
#
# ** AUC/ROC:
# ** Confusion Matrix:

# %% [markdown]
# ## 3.2. XGBoost

# %% [markdown]
# ### 3.2.1. Train

# %%
from xgboost import XGBClassifier

# %%
train_y.mean(), 1/train_y.mean()
# Out:
# (0.15450121654501217, 6.47244094488189)

# %%
xgb_model = XGBClassifier(
    n_estimators=100,
    max_depth=5,
    scale_pos_weight=1/train_y.mean(),
)

# %%
# %%time

xgb_model.fit(train_x, train_y)
# Out:
# CPU times: user 4.43 s, sys: 206 ms, total: 4.64 s
# Wall time: 320 ms
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %% [markdown]
# ### 3.2.2. Eval

# %%
xgb_pred = xgb_model.predict(test_x)

# %%
xgb_pred_proba = xgb_model.predict_proba(test_x)[:,1]

# %%
eval_func(test_y, xgb_pred, xgb_pred_proba)
# Out:
# ** Key Metrics:
# Accuracy: 86.6%, Precision: 54.9%, Recall: 79.2%
#
#
# ** AUC/ROC:
# ** Confusion Matrix:

# %% [markdown]
# # 4. Deep Learning Based Modeling

# %%
import keras
# Out:
# 2024-04-16 07:50:09.558769: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 4.0. Normalize

# %%
mean = train_x.mean()
std = train_x.std()

# %%
normed_train_x = (train_x - mean)/std
normed_test_x = (test_x - mean)/std

# %%
print("** Mean: ")
display(pd.DataFrame(mean))

print("** STD: ")
display(pd.DataFrame(std))
# Out:
# ** Mean:
#                                    0
# Administrative              2.304745
# Administrative_Duration    80.442878
# BounceRates                 0.022473
# Browser                     2.339619
# ExitRates                   0.043376
# Informational               0.500710
# Informational_Duration     35.041119
# MonthNum                    7.636050
# OperatingSystems            2.121857
# PageValues                  5.842192
# ProductRelated             31.715126
# ProductRelated_Duration  1194.410925
# Region                      3.133820
# SpecialDay                  0.061577
# TrafficType                 4.071675
# VisitorTypeNum              0.869728
# Weekend                     0.231042
# ** STD:
#                                    0
# Administrative              3.312479
# Administrative_Duration   175.872996
# BounceRates                 0.048757
# Browser                     1.701199
# ExitRates                   0.048707
# Informational               1.264558
# Informational_Duration    142.434615
# MonthNum                    3.388666
# OperatingSystems            0.916106
# PageValues                 18.774015
# ProductRelated             43.653744
# ProductRelated_Duration  1800.417452
# Region                      2.391589
# SpecialDay                  0.198503
# TrafficType                 4.015739
# VisitorTypeNum              0.356513
# Weekend                     0.421521

# %%
print("** Normed Mean: ")
display(pd.DataFrame(normed_train_x.mean()))

print("** Normed STD: ")
display(pd.DataFrame(normed_train_x.std()))
# Out:
# ** Normed Mean:
#                                     0
# Administrative          -3.889832e-17
# Administrative_Duration -8.644072e-18
# BounceRates             -5.546613e-17
# Browser                  2.953391e-17
# ExitRates               -1.030085e-16
# Informational           -6.194918e-17
# Informational_Duration   2.269069e-17
# MonthNum                -8.860174e-17
# OperatingSystems        -8.500004e-17
# PageValues              -1.584747e-17
# ProductRelated          -1.512713e-17
# ProductRelated_Duration  2.737290e-17
# Region                  -4.970342e-17
# SpecialDay               8.103818e-17
# TrafficType              1.980933e-17
# VisitorTypeNum           4.610172e-17
# Weekend                 -9.652547e-17
# ** Normed STD:
#                            0
# Administrative           1.0
# Administrative_Duration  1.0
# BounceRates              1.0
# Browser                  1.0
# ExitRates                1.0
# Informational            1.0
# Informational_Duration   1.0
# MonthNum                 1.0
# OperatingSystems         1.0
# PageValues               1.0
# ProductRelated           1.0
# ProductRelated_Duration  1.0
# Region                   1.0
# SpecialDay               1.0
# TrafficType              1.0
# VisitorTypeNum           1.0
# Weekend                  1.0

# %% [markdown]
# ## 4.1. Wide Net

# %%
model = keras.Sequential(
    [
        keras.Input(shape=normed_train_x.shape[1:]),
        keras.layers.Dense(2048, activation="relu"),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation="sigmoid"),
    ]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2048)              36864
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 38,913
# Trainable params: 38,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 4.1.1. Train

# %%
model_metrics = [
    keras.metrics.Accuracy(name="accuracy"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
]

model.compile(
    optimizer=keras.optimizers.Adam(0.001), loss="binary_crossentropy", metrics=model_metrics
)

best_model_path = "./checkpoint.wide-model.keras"

early_stopping_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=0.001,
    patience=3
)
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=best_model_path,
    monitor="val_precision",
    mode="max",
    save_best_only=True
)

class_weight = {0: 1, 1: 1/train_y.mean()}

history = model.fit(
    normed_train_x.to_numpy(),
    train_y.to_numpy(),
    batch_size=64,
    epochs=30,
    verbose=2,
    callbacks=[
        # early_stopping_callback, 
        model_checkpoint_callback,
    ],
    validation_data=(normed_test_x.to_numpy(), test_y.to_numpy()),
    class_weight=class_weight,
)
# Out:
# Epoch 1/30
# 155/155 - 1s - loss: 0.8329 - accuracy: 6.0827e-04 - precision: 0.3857 - recall: 0.8005 - val_loss: 0.4306 - val_accuracy: 8.1103e-04 - val_precision: 0.4984 - val_recall: 0.8021 - 1s/epoch - 8ms/step
# Epoch 2/30
# 155/155 - 0s - loss: 0.7331 - accuracy: 5.0689e-04 - precision: 0.4616 - recall: 0.8196 - val_loss: 0.4216 - val_accuracy: 4.0551e-04 - val_precision: 0.4715 - val_recall: 0.8411 - 296ms/epoch - 2ms/step
# Epoch 3/30
# 155/155 - 0s - loss: 0.6960 - accuracy: 2.0276e-04 - precision: 0.4615 - recall: 0.8386 - val_loss: 0.4009 - val_accuracy: 0.0000e+00 - val_precision: 0.4769 - val_recall: 0.8333 - 329ms/epoch - 2ms/step
# Epoch 4/30
# 155/155 - 0s - loss: 0.6771 - accuracy: 0.0000e+00 - precision: 0.4759 - recall: 0.8432 - val_loss: 0.4259 - val_accuracy: 0.0000e+00 - val_precision: 0.4779 - val_recall: 0.8438 - 293ms/epoch - 2ms/step
# Epoch 5/30
# 155/155 - 0s - loss: 0.6620 - accuracy: 0.0000e+00 - precision: 0.4798 - recall: 0.8406 - val_loss: 0.3730 - val_accuracy: 0.0000e+00 - val_precision: 0.4930 - val_recall: 0.8255 - 311ms/epoch - 2ms/step
# Epoch 6/30
# 155/155 - 0s - loss: 0.6537 - accuracy: 0.0000e+00 - precision: 0.4725 - recall: 0.8471 - val_loss: 0.3903 - val_accuracy: 0.0000e+00 - val_precision: 0.5031 - val_recall: 0.8411 - 307ms/epoch - 2ms/step
# Epoch 7/30
# 155/155 - 0s - loss: 0.6514 - accuracy: 0.0000e+00 - precision: 0.4657 - recall: 0.8465 - val_loss: 0.4063 - val_accuracy: 0.0000e+00 - val_precision: 0.4713 - val_recall: 0.8542 - 294ms/epoch - 2ms/step
# Epoch 8/30
# 155/155 - 0s - loss: 0.6347 - accuracy: 0.0000e+00 - precision: 0.4966 - recall: 0.8530 - val_loss: 0.4374 - val_accuracy: 0.0000e+00 - val_precision: 0.4465 - val_recall: 0.8802 - 294ms/epoch - 2ms/step
# Epoch 9/30
# 155/155 - 0s - loss: 0.6364 - accuracy: 0.0000e+00 - precision: 0.4876 - recall: 0.8517 - val_loss: 0.4417 - val_accuracy: 0.0000e+00 - val_precision: 0.4701 - val_recall: 0.8594 - 290ms/epoch - 2ms/step
# Epoch 10/30
# 155/155 - 0s - loss: 0.6194 - accuracy: 0.0000e+00 - precision: 0.4911 - recall: 0.8537 - val_loss: 0.4506 - val_accuracy: 0.0000e+00 - val_precision: 0.4183 - val_recall: 0.8672 - 290ms/epoch - 2ms/step
# Epoch 11/30
# 155/155 - 0s - loss: 0.6168 - accuracy: 0.0000e+00 - precision: 0.4939 - recall: 0.8530 - val_loss: 0.4296 - val_accuracy: 0.0000e+00 - val_precision: 0.4635 - val_recall: 0.8594 - 289ms/epoch - 2ms/step
# Epoch 12/30
# 155/155 - 0s - loss: 0.6185 - accuracy: 0.0000e+00 - precision: 0.4885 - recall: 0.8602 - val_loss: 0.4150 - val_accuracy: 0.0000e+00 - val_precision: 0.4694 - val_recall: 0.8594 - 289ms/epoch - 2ms/step
# Epoch 13/30
# 155/155 - 0s - loss: 0.6075 - accuracy: 0.0000e+00 - precision: 0.4855 - recall: 0.8661 - val_loss: 0.3956 - val_accuracy: 0.0000e+00 - val_precision: 0.4755 - val_recall: 0.8333 - 296ms/epoch - 2ms/step
# Epoch 14/30
# 155/155 - 0s - loss: 0.6059 - accuracy: 0.0000e+00 - precision: 0.5010 - recall: 0.8648 - val_loss: 0.4095 - val_accuracy: 0.0000e+00 - val_precision: 0.4605 - val_recall: 0.8646 - 297ms/epoch - 2ms/step
# Epoch 15/30
# 155/155 - 0s - loss: 0.5981 - accuracy: 0.0000e+00 - precision: 0.4955 - recall: 0.8655 - val_loss: 0.4004 - val_accuracy: 0.0000e+00 - val_precision: 0.4851 - val_recall: 0.8464 - 292ms/epoch - 2ms/step
# Epoch 16/30
# 155/155 - 0s - loss: 0.5926 - accuracy: 0.0000e+00 - precision: 0.5034 - recall: 0.8701 - val_loss: 0.3441 - val_accuracy: 0.0000e+00 - val_precision: 0.5209 - val_recall: 0.8099 - 323ms/epoch - 2ms/step
# Epoch 17/30
# 155/155 - 0s - loss: 0.5919 - accuracy: 0.0000e+00 - precision: 0.5006 - recall: 0.8615 - val_loss: 0.4084 - val_accuracy: 0.0000e+00 - val_precision: 0.4875 - val_recall: 0.8620 - 303ms/epoch - 2ms/step
# Epoch 18/30
# 155/155 - 0s - loss: 0.5828 - accuracy: 0.0000e+00 - precision: 0.5028 - recall: 0.8819 - val_loss: 0.3850 - val_accuracy: 0.0000e+00 - val_precision: 0.4977 - val_recall: 0.8464 - 303ms/epoch - 2ms/step
# Epoch 19/30
# 155/155 - 0s - loss: 0.5789 - accuracy: 0.0000e+00 - precision: 0.5163 - recall: 0.8734 - val_loss: 0.4285 - val_accuracy: 0.0000e+00 - val_precision: 0.4458 - val_recall: 0.8672 - 326ms/epoch - 2ms/step
# Epoch 20/30
# 155/155 - 0s - loss: 0.5788 - accuracy: 0.0000e+00 - precision: 0.4996 - recall: 0.8832 - val_loss: 0.3816 - val_accuracy: 0.0000e+00 - val_precision: 0.4820 - val_recall: 0.8359 - 296ms/epoch - 2ms/step
# Epoch 21/30
# 155/155 - 0s - loss: 0.5719 - accuracy: 0.0000e+00 - precision: 0.5105 - recall: 0.8766 - val_loss: 0.4354 - val_accuracy: 0.0000e+00 - val_precision: 0.4485 - val_recall: 0.8958 - 293ms/epoch - 2ms/step
# Epoch 22/30
# 155/155 - 0s - loss: 0.5642 - accuracy: 0.0000e+00 - precision: 0.5150 - recall: 0.8812 - val_loss: 0.3645 - val_accuracy: 0.0000e+00 - val_precision: 0.5161 - val_recall: 0.8359 - 309ms/epoch - 2ms/step
# Epoch 23/30
# 155/155 - 0s - loss: 0.5626 - accuracy: 0.0000e+00 - precision: 0.5085 - recall: 0.8871 - val_loss: 0.3543 - val_accuracy: 0.0000e+00 - val_precision: 0.5097 - val_recall: 0.8203 - 302ms/epoch - 2ms/step
# Epoch 24/30
# 155/155 - 0s - loss: 0.5626 - accuracy: 0.0000e+00 - precision: 0.5073 - recall: 0.8937 - val_loss: 0.3560 - val_accuracy: 0.0000e+00 - val_precision: 0.5223 - val_recall: 0.8229 - 309ms/epoch - 2ms/step
# Epoch 25/30
# 155/155 - 0s - loss: 0.5540 - accuracy: 0.0000e+00 - precision: 0.5128 - recall: 0.8911 - val_loss: 0.4312 - val_accuracy: 0.0000e+00 - val_precision: 0.4569 - val_recall: 0.8698 - 300ms/epoch - 2ms/step
# Epoch 26/30
# 155/155 - 0s - loss: 0.5472 - accuracy: 0.0000e+00 - precision: 0.5192 - recall: 0.8944 - val_loss: 0.4383 - val_accuracy: 0.0000e+00 - val_precision: 0.4694 - val_recall: 0.8594 - 304ms/epoch - 2ms/step
# Epoch 27/30
# 155/155 - 0s - loss: 0.5436 - accuracy: 0.0000e+00 - precision: 0.5204 - recall: 0.8957 - val_loss: 0.4095 - val_accuracy: 0.0000e+00 - val_precision: 0.4822 - val_recall: 0.8464 - 293ms/epoch - 2ms/step
# Epoch 28/30
# 155/155 - 0s - loss: 0.5453 - accuracy: 0.0000e+00 - precision: 0.5178 - recall: 0.8878 - val_loss: 0.4060 - val_accuracy: 0.0000e+00 - val_precision: 0.4705 - val_recall: 0.8516 - 296ms/epoch - 2ms/step
# Epoch 29/30
# 155/155 - 0s - loss: 0.5322 - accuracy: 0.0000e+00 - precision: 0.5209 - recall: 0.8990 - val_loss: 0.3902 - val_accuracy: 0.0000e+00 - val_precision: 0.4939 - val_recall: 0.8438 - 335ms/epoch - 2ms/step
# Epoch 30/30
# 155/155 - 0s - loss: 0.5268 - accuracy: 0.0000e+00 - precision: 0.5282 - recall: 0.8983 - val_loss: 0.3958 - val_accuracy: 0.0000e+00 - val_precision: 0.4766 - val_recall: 0.8490 - 294ms/epoch - 2ms/step

# %%
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# ### 4.1.2. Eval

# %%
wide_best_model = keras.models.load_model(best_model_path)

# %%
wide_best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2048)              36864
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 38,913
# Trainable params: 38,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
wide_pred_proba = wide_best_model.predict(normed_test_x).flatten()
# Out:
# 78/78 [==============================] - 0s 616us/step

# %%
wide_preds = [1 if x > 0.5 else 0 for x in wide_pred_proba]

# %%
eval_func(test_y, wide_preds, wide_pred_proba)
# Out:
# ** Key Metrics:
# Accuracy: 85.5%, Precision: 52.2%, Recall: 82.3%
#
#
# ** AUC/ROC:
# ** Confusion Matrix:

# %% [markdown]
# ## 4.2. Deep Net

# %%
model = keras.Sequential(
    [
        keras.Input(shape=normed_train_x.shape[1:]),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation="sigmoid"),
    ]
)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 128)               2304
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 35,457
# Trainable params: 35,457
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 4.2.1. Train

# %%
model_metrics = [
    keras.metrics.Accuracy(name="accuracy"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
]

model.compile(
    optimizer=keras.optimizers.Adam(0.001), loss="binary_crossentropy", metrics=model_metrics
)

best_model_path = "./checkpoint.deep-model.keras"

early_stopping_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=0.001,
    patience=3
)
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=best_model_path,
    monitor="val_precision",
    mode="max",
    save_best_only=True
)

class_weight = {0: 1, 1: 1/train_y.mean()}

history = model.fit(
    normed_train_x.to_numpy(),
    train_y.to_numpy(),
    batch_size=64,
    epochs=30,
    verbose=2,
    callbacks=[
        # early_stopping_callback, 
        model_checkpoint_callback,
    ],
    validation_data=(normed_test_x.to_numpy(), test_y.to_numpy()),
    class_weight=class_weight,
)
# Out:
# Epoch 1/30
# 155/155 - 1s - loss: 0.8580 - accuracy: 7.0965e-04 - precision: 0.3722 - recall: 0.8110 - val_loss: 0.4415 - val_accuracy: 4.0551e-04 - val_precision: 0.4422 - val_recall: 0.8073 - 1s/epoch - 7ms/step
# Epoch 2/30
# 155/155 - 0s - loss: 0.7432 - accuracy: 3.0414e-04 - precision: 0.4435 - recall: 0.8399 - val_loss: 0.3669 - val_accuracy: 4.0551e-04 - val_precision: 0.5221 - val_recall: 0.7995 - 295ms/epoch - 2ms/step
# Epoch 3/30
# 155/155 - 0s - loss: 0.7094 - accuracy: 3.0414e-04 - precision: 0.4532 - recall: 0.8412 - val_loss: 0.5199 - val_accuracy: 0.0000e+00 - val_precision: 0.3916 - val_recall: 0.9036 - 241ms/epoch - 2ms/step
# Epoch 4/30
# 155/155 - 0s - loss: 0.6733 - accuracy: 2.0276e-04 - precision: 0.4578 - recall: 0.8615 - val_loss: 0.4192 - val_accuracy: 0.0000e+00 - val_precision: 0.4651 - val_recall: 0.8672 - 251ms/epoch - 2ms/step
# Epoch 5/30
# 155/155 - 0s - loss: 0.6517 - accuracy: 0.0000e+00 - precision: 0.4666 - recall: 0.8583 - val_loss: 0.3770 - val_accuracy: 0.0000e+00 - val_precision: 0.4923 - val_recall: 0.8281 - 249ms/epoch - 2ms/step
# Epoch 6/30
# 155/155 - 0s - loss: 0.6399 - accuracy: 0.0000e+00 - precision: 0.4739 - recall: 0.8642 - val_loss: 0.4294 - val_accuracy: 0.0000e+00 - val_precision: 0.4406 - val_recall: 0.8698 - 248ms/epoch - 2ms/step
# Epoch 7/30
# 155/155 - 0s - loss: 0.6160 - accuracy: 0.0000e+00 - precision: 0.4778 - recall: 0.8760 - val_loss: 0.3686 - val_accuracy: 0.0000e+00 - val_precision: 0.4924 - val_recall: 0.8464 - 246ms/epoch - 2ms/step
# Epoch 8/30
# 155/155 - 0s - loss: 0.5972 - accuracy: 0.0000e+00 - precision: 0.4863 - recall: 0.8819 - val_loss: 0.4358 - val_accuracy: 0.0000e+00 - val_precision: 0.4232 - val_recall: 0.8828 - 246ms/epoch - 2ms/step
# Epoch 9/30
# 155/155 - 0s - loss: 0.5931 - accuracy: 0.0000e+00 - precision: 0.4843 - recall: 0.8878 - val_loss: 0.4022 - val_accuracy: 0.0000e+00 - val_precision: 0.4568 - val_recall: 0.8542 - 265ms/epoch - 2ms/step
# Epoch 10/30
# 155/155 - 0s - loss: 0.5795 - accuracy: 0.0000e+00 - precision: 0.4879 - recall: 0.8898 - val_loss: 0.4211 - val_accuracy: 0.0000e+00 - val_precision: 0.4453 - val_recall: 0.8594 - 245ms/epoch - 2ms/step
# Epoch 11/30
# 155/155 - 0s - loss: 0.5785 - accuracy: 0.0000e+00 - precision: 0.4873 - recall: 0.8930 - val_loss: 0.3872 - val_accuracy: 0.0000e+00 - val_precision: 0.4420 - val_recall: 0.8542 - 244ms/epoch - 2ms/step
# Epoch 12/30
# 155/155 - 0s - loss: 0.5649 - accuracy: 0.0000e+00 - precision: 0.4880 - recall: 0.8944 - val_loss: 0.3794 - val_accuracy: 0.0000e+00 - val_precision: 0.4632 - val_recall: 0.8516 - 243ms/epoch - 2ms/step
# Epoch 13/30
# 155/155 - 0s - loss: 0.5508 - accuracy: 0.0000e+00 - precision: 0.4934 - recall: 0.9108 - val_loss: 0.3484 - val_accuracy: 0.0000e+00 - val_precision: 0.5113 - val_recall: 0.8229 - 244ms/epoch - 2ms/step
# Epoch 14/30
# 155/155 - 0s - loss: 0.5390 - accuracy: 0.0000e+00 - precision: 0.4936 - recall: 0.9094 - val_loss: 0.3749 - val_accuracy: 0.0000e+00 - val_precision: 0.4902 - val_recall: 0.8438 - 243ms/epoch - 2ms/step
# Epoch 15/30
# 155/155 - 0s - loss: 0.5318 - accuracy: 0.0000e+00 - precision: 0.4931 - recall: 0.9088 - val_loss: 0.4044 - val_accuracy: 0.0000e+00 - val_precision: 0.4658 - val_recall: 0.8516 - 249ms/epoch - 2ms/step
# Epoch 16/30
# 155/155 - 0s - loss: 0.5289 - accuracy: 0.0000e+00 - precision: 0.4910 - recall: 0.9173 - val_loss: 0.3770 - val_accuracy: 0.0000e+00 - val_precision: 0.4761 - val_recall: 0.8307 - 244ms/epoch - 2ms/step
# Epoch 17/30
# 155/155 - 0s - loss: 0.5242 - accuracy: 0.0000e+00 - precision: 0.4971 - recall: 0.9134 - val_loss: 0.3506 - val_accuracy: 0.0000e+00 - val_precision: 0.4871 - val_recall: 0.8359 - 246ms/epoch - 2ms/step
# Epoch 18/30
# 155/155 - 0s - loss: 0.5066 - accuracy: 0.0000e+00 - precision: 0.5088 - recall: 0.9272 - val_loss: 0.4727 - val_accuracy: 0.0000e+00 - val_precision: 0.3931 - val_recall: 0.8958 - 244ms/epoch - 2ms/step
# Epoch 19/30
# 155/155 - 0s - loss: 0.4969 - accuracy: 0.0000e+00 - precision: 0.5178 - recall: 0.9245 - val_loss: 0.3978 - val_accuracy: 0.0000e+00 - val_precision: 0.4652 - val_recall: 0.8359 - 241ms/epoch - 2ms/step
# Epoch 20/30
# 155/155 - 0s - loss: 0.4921 - accuracy: 0.0000e+00 - precision: 0.5122 - recall: 0.9245 - val_loss: 0.3857 - val_accuracy: 0.0000e+00 - val_precision: 0.4751 - val_recall: 0.8464 - 241ms/epoch - 2ms/step
# Epoch 21/30
# 155/155 - 0s - loss: 0.4825 - accuracy: 0.0000e+00 - precision: 0.5068 - recall: 0.9318 - val_loss: 0.4360 - val_accuracy: 0.0000e+00 - val_precision: 0.4472 - val_recall: 0.8594 - 244ms/epoch - 2ms/step
# Epoch 22/30
# 155/155 - 0s - loss: 0.4986 - accuracy: 0.0000e+00 - precision: 0.4989 - recall: 0.9304 - val_loss: 0.3862 - val_accuracy: 0.0000e+00 - val_precision: 0.4475 - val_recall: 0.8438 - 241ms/epoch - 2ms/step
# Epoch 23/30
# 155/155 - 0s - loss: 0.4762 - accuracy: 0.0000e+00 - precision: 0.5231 - recall: 0.9285 - val_loss: 0.3982 - val_accuracy: 0.0000e+00 - val_precision: 0.4586 - val_recall: 0.8359 - 244ms/epoch - 2ms/step
# Epoch 24/30
# 155/155 - 0s - loss: 0.4640 - accuracy: 0.0000e+00 - precision: 0.5254 - recall: 0.9370 - val_loss: 0.4268 - val_accuracy: 0.0000e+00 - val_precision: 0.4540 - val_recall: 0.8490 - 242ms/epoch - 2ms/step
# Epoch 25/30
# 155/155 - 0s - loss: 0.4661 - accuracy: 0.0000e+00 - precision: 0.5129 - recall: 0.9416 - val_loss: 0.3882 - val_accuracy: 0.0000e+00 - val_precision: 0.4893 - val_recall: 0.8333 - 242ms/epoch - 2ms/step
# Epoch 26/30
# 155/155 - 0s - loss: 0.4474 - accuracy: 0.0000e+00 - precision: 0.5282 - recall: 0.9331 - val_loss: 0.3829 - val_accuracy: 0.0000e+00 - val_precision: 0.4671 - val_recall: 0.8307 - 239ms/epoch - 2ms/step
# Epoch 27/30
# 155/155 - 0s - loss: 0.4559 - accuracy: 0.0000e+00 - precision: 0.5183 - recall: 0.9377 - val_loss: 0.4678 - val_accuracy: 0.0000e+00 - val_precision: 0.4536 - val_recall: 0.8281 - 263ms/epoch - 2ms/step
# Epoch 28/30
# 155/155 - 0s - loss: 0.4385 - accuracy: 0.0000e+00 - precision: 0.5326 - recall: 0.9442 - val_loss: 0.4102 - val_accuracy: 0.0000e+00 - val_precision: 0.4507 - val_recall: 0.8333 - 243ms/epoch - 2ms/step
# Epoch 29/30
# 155/155 - 0s - loss: 0.4305 - accuracy: 0.0000e+00 - precision: 0.5313 - recall: 0.9475 - val_loss: 0.3836 - val_accuracy: 0.0000e+00 - val_precision: 0.5090 - val_recall: 0.8073 - 247ms/epoch - 2ms/step
# Epoch 30/30
# 155/155 - 0s - loss: 0.4448 - accuracy: 1.0138e-04 - precision: 0.5328 - recall: 0.9370 - val_loss: 0.3841 - val_accuracy: 0.0000e+00 - val_precision: 0.4976 - val_recall: 0.8177 - 246ms/epoch - 2ms/step

# %%
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# ### 4.1.2. Eval

# %%
deep_best_model = keras.models.load_model(best_model_path)

# %%
deep_best_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 128)               2304
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 35,457
# Trainable params: 35,457
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_pred_proba = deep_best_model.predict(normed_test_x).flatten()
# Out:
# 78/78 [==============================] - 0s 636us/step

# %%
deep_preds = [1 if x > 0.5 else 0 for x in deep_pred_proba]

# %%
eval_func(test_y, deep_preds, deep_pred_proba)
# Out:
# ** Key Metrics:
# Accuracy: 85.5%, Precision: 52.2%, Recall: 79.9%
#
#
# ** AUC/ROC:
# ** Confusion Matrix:

# %% [markdown]
# # 5. A/B Testing

# %%
test_y.shape
# Out:
# (2466,)

# %% [markdown]
# ## 5.1. Random Selection of Test Groups

# %%
group_a_indexes = sorted(list(np.random.choice(2000, 1000, replace=False)))
group_b_indexes = [x for x in range(2000) if x not in group_a_indexes]

# %%
len(group_a_indexes)
# Out:
# 1000

# %%
np.min(group_a_indexes), np.max(group_a_indexes)
# Out:
# (0, 1996)

# %%
len(group_b_indexes)
# Out:
# 1000

# %%
np.min(group_b_indexes), np.max(group_b_indexes)
# Out:
# (1, 1999)

# %% [markdown]
# ## 5.2. XGBoost vs. Wide Net A/B Testing Simulation

# %%
from tqdm import tqdm

# %%
group_a_actuals = test_y.iloc[group_a_indexes].to_numpy()
group_b_actuals = test_y.iloc[group_b_indexes].to_numpy()

group_a_preds = []
group_b_preds = []

for customer in tqdm(range(2000)):
    if customer in group_a_indexes:
        # route to XGBoost
        conversion = test_y.iloc[customer]
        pred_prob = xgb_model.predict_proba(
            np.array([test_x.iloc[customer].to_numpy(),])
        )[0][1]
        pred = 1 if pred_prob > 0.5 else 0
        group_a_preds.append(pred)
    elif customer in group_b_indexes:
        # route to Wide Net
        conversion = test_y.iloc[customer]
        pred_prob = wide_best_model.predict(
            np.array([normed_test_x.iloc[customer].to_numpy(),]), verbose=0
        )[0][0]
        pred = 1 if pred_prob > 0.5 else 0
        group_b_preds.append(pred)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:57<00:00, 34.88it/s]

# %%
np.sum(group_a_preds), np.sum(group_a_actuals)
# Out:
# (225, 154)

# %%
def get_cumulative_metrics(actuals, preds):
    cum_conversions = []
    missed_opportunities = []
    
    customer_counter = 0
    cum_conversion_count = 0
    missed_opp_count = 0
    for actual, pred in zip(actuals, preds):
        customer_counter += 1
        if pred == 1:
            if actual == 1:
                cum_conversion_count += 1
        else:
            if actual == 1:
                missed_opp_count += 1
        cum_conversions.append(cum_conversion_count/customer_counter)
        missed_opportunities.append(missed_opp_count/customer_counter)
    return cum_conversions, missed_opportunities

# %%
a_cum_conv_rates, a_missed_opp_rates = get_cumulative_metrics(group_a_actuals, group_a_preds)
b_cum_conv_rates, b_missed_opp_rates = get_cumulative_metrics(group_b_actuals, group_b_preds)

# %%
ab_results_df = pd.DataFrame({
    "group_a_cum_conversion_rate": a_cum_conv_rates, 
    "group_a_cum_missed_opportunity_rate": a_missed_opp_rates,
    "group_b_cum_conversion_rate": b_cum_conv_rates, 
    "group_b_cum_missed_opportunity_rate": b_missed_opp_rates,
})

# %%
ax = (
    ab_results_df[[
        "group_a_cum_conversion_rate", "group_b_cum_conversion_rate"
    ]]*100
).plot(
    figsize=(8, 5),
    grid=True
)

ax.set_ylabel("Conversion Rate (%)")
ax.set_xlabel("Customer Count")
ax.set_title("Cumulative Conversion Rates over Time (A: XGBoost, B: Wide Net)")
plt.show()

# %%
ax = (
    ab_results_df[[
        "group_a_cum_missed_opportunity_rate", "group_b_cum_missed_opportunity_rate"
    ]]*100
).plot(
    figsize=(8, 5),
    grid=True
)

ax.set_ylabel("Missed Opportunity Rate (%)")
ax.set_xlabel("Customer Count")
ax.set_title("Cumulative Missed Opportunity Rates over Time (A: XGBoost, B: Wide Net)")
plt.show()

# %% [markdown]
# ## 5.3. Significance Test

# %% [markdown]
# ### 5.3.1. Testing Cumulative Distribution

# %%
from scipy.stats import ttest_ind

# %%
# Performing the t-test
t, p = ttest_ind(a_cum_conv_rates, b_cum_conv_rates)
print(f"Conversion Rate Difference Significance -- t: {t:.3f} & p: {p:.3f}")
# Out:
# Conversion Rate Difference Significance -- t: 24.712 & p: 0.000

# %%
t, p = ttest_ind(a_missed_opp_rates, b_missed_opp_rates)
print(f"Missed Opportunity Rate Difference Significance -- t: {t:.3f} & p: {p:.3f}")
# Out:
# Missed Opportunity Rate Difference Significance -- t: -1.832 & p: 0.067

# %% [markdown]
# ### 5.3.2. Testing Mean

# %%
from scipy.stats import t as tstat

# %% [markdown]
# #### Conversion Rate Test --> XGBoost Wins
#
# XGBoost has significantly higher conversion rate

# %%
a_conv_rate = a_cum_conv_rates[-1]
b_conv_rate = b_cum_conv_rates[-1]

a_conv_rate, b_conv_rate
# Out:
# (0.129, 0.123)

# %%
sample_size = 1000

a_mean = a_conv_rate * sample_size
b_mean = b_conv_rate * sample_size

a_std = np.sqrt(sample_size*a_conv_rate*(1-a_conv_rate))
b_std = np.sqrt(sample_size*b_conv_rate*(1-b_conv_rate))

a_mean, a_std, b_mean, b_std
# Out:
# (129.0, 10.599952830083726, 123.0, 10.386096475577338)

# %%
t_score = (a_mean - b_mean)/np.sqrt( (a_std**2)/sample_size + (b_std**2)/sample_size )
t_score
# Out:
# 12.785361470052457

# %%
pvalue = tstat.sf(np.abs(t_score), sample_size-1) * 2
print(f"p-value: {pvalue:.03f}")
# Out:
# p-value: 0.000

# %% [markdown]
# #### Missed Opportunity Rate Test --> XGBoost Wins
#
# Wide Net has significantly higher missed opportunity rate

# %%
a_missed_opp_rate = a_missed_opp_rates[-1]
b_missed_opp_rate = b_missed_opp_rates[-1]

a_missed_opp_rate, b_missed_opp_rate
# Out:
# (0.025, 0.027)

# %%
sample_size = 1000

a_mean = a_missed_opp_rate * sample_size
b_mean = b_missed_opp_rate * sample_size

a_std = np.sqrt(sample_size*a_conv_rate*(1-a_conv_rate))
b_std = np.sqrt(sample_size*b_conv_rate*(1-b_conv_rate))

a_mean, a_std, b_mean, b_std
# Out:
# (25.0, 10.599952830083726, 27.0, 10.386096475577338)

# %%
t_score = (a_mean - b_mean)/np.sqrt( (a_std**2)/sample_size + (b_std**2)/sample_size )
t_score
# Out:
# -4.261787156684153

# %%
pvalue = tstat.sf(np.abs(t_score), sample_size-1) * 2
print(f"p-value: {pvalue:.03f}")
# Out:
# p-value: 0.000
