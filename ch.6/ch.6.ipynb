# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # 0. Data
#
# Source & Description: https://archive.ics.uci.edu/dataset/468/online+shoppers+purchasing+intention+dataset

# %%
df = pd.read_csv("./data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12330 entries, 0 to 12329
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12330 non-null  int64
#  1   Administrative_Duration  12330 non-null  float64
#  2   Informational            12330 non-null  int64
#  3   Informational_Duration   12330 non-null  float64
#  4   ProductRelated           12330 non-null  int64
#  5   ProductRelated_Duration  12330 non-null  float64
#  6   BounceRates              12330 non-null  float64
#  7   ExitRates                12330 non-null  float64
#  8   PageValues               12330 non-null  float64
#  9   SpecialDay               12330 non-null  float64
#  10  Month                    12330 non-null  object
#  11  OperatingSystems         12330 non-null  int64
#  12  Browser                  12330 non-null  int64
#  13  Region                   12330 non-null  int64
#  14  TrafficType              12330 non-null  int64
#  15  VisitorType              12330 non-null  object
#  16  Weekend                  12330 non-null  bool
#  17  Revenue                  12330 non-null  bool
# dtypes: bool(2), float64(7), int64(7), object(2)
# memory usage: 1.5+ MB

# %%
df.tail()
# Out:
#        Administrative  Administrative_Duration  Informational  \
# 12325               3                    145.0              0
# 12326               0                      0.0              0
# 12327               0                      0.0              0
# 12328               4                     75.0              0
# 12329               0                      0.0              0
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 12325                     0.0              53              1783.791667
# 12326                     0.0               5               465.750000
# 12327                     0.0               6               184.250000
# 12328                     0.0              15               346.000000
# 12329                     0.0               3                21.250000
#
#        BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 12325     0.007143   0.029031   12.241717         0.0   Dec                 4
# 12326     0.000000   0.021333    0.000000         0.0   Nov                 3
# 12327     0.083333   0.086667    0.000000         0.0   Nov                 3
# 12328     0.000000   0.021053    0.000000         0.0   Nov                 2
# 12329     0.000000   0.066667    0.000000         0.0   Nov                 3
#
#        Browser  Region  TrafficType        VisitorType  Weekend  Revenue
# 12325        6       1            1  Returning_Visitor     True    False
# 12326        2       1            8  Returning_Visitor     True    False
# 12327        2       1           13  Returning_Visitor     True    False
# 12328        2       3           11  Returning_Visitor    False    False
# 12329        2       1            2        New_Visitor     True    False

# %% [markdown]
# # 1. Encoding

# %% [markdown]
# ## Month Encoding

# %%
from time import strptime

# %%
df["Month"].unique()
# Out:
# array(['Feb', 'Mar', 'May', 'Oct', 'June', 'Jul', 'Aug', 'Nov', 'Sep',
#        'Dec'], dtype=object)

# %%
df["MonthNum"] = df["Month"].apply(lambda x: strptime(x[:3],'%b').tm_mon)

# %%
df["MonthNum"].unique()
# Out:
# array([ 2,  3,  5, 10,  6,  7,  8, 11,  9, 12])

# %% [markdown]
# ## Visitor Type Encoding

# %%
df["VisitorType"].unique()
# Out:
# array(['Returning_Visitor', 'New_Visitor', 'Other'], dtype=object)

# %%
df["VisitorTypeNum"] = df["VisitorType"].apply(lambda x: 0 if x == "New_Visitor" else 1 if x == "Returning_Visitor" else 2)

# %%
df["VisitorTypeNum"].unique()
# Out:
# array([1, 0, 2])

# %% [markdown]
# ## Weekend Encoding

# %%
df["Weekend"].unique()
# Out:
# array([False,  True])

# %%
df["Weekend"] = df["Weekend"].astype(int)

# %%
df["Weekend"].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ## Revenue Encoding

# %%
df["Revenue"].unique()
# Out:
# array([False,  True])

# %%
df["Revenue"] = df["Revenue"].astype(int)

# %%
df["Revenue"].unique()
# Out:
# array([0, 1])

# %% [markdown]
# ## Results

# %%
df.describe()
# Out:
#        Administrative  Administrative_Duration  Informational  \
# count    12330.000000             12330.000000   12330.000000
# mean         2.315166                80.818611       0.503569
# std          3.321784               176.779107       1.270156
# min          0.000000                 0.000000       0.000000
# 25%          0.000000                 0.000000       0.000000
# 50%          1.000000                 7.500000       0.000000
# 75%          4.000000                93.256250       0.000000
# max         27.000000              3398.750000      24.000000
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# count            12330.000000    12330.000000             12330.000000
# mean                34.472398       31.731468              1194.746220
# std                140.749294       44.475503              1913.669288
# min                  0.000000        0.000000                 0.000000
# 25%                  0.000000        7.000000               184.137500
# 50%                  0.000000       18.000000               598.936905
# 75%                  0.000000       38.000000              1464.157214
# max               2549.375000      705.000000             63973.522230
#
#         BounceRates     ExitRates    PageValues    SpecialDay  \
# count  12330.000000  12330.000000  12330.000000  12330.000000
# mean       0.022191      0.043073      5.889258      0.061427
# std        0.048488      0.048597     18.568437      0.198917
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.014286      0.000000      0.000000
# 50%        0.003112      0.025156      0.000000      0.000000
# 75%        0.016813      0.050000      0.000000      0.000000
# max        0.200000      0.200000    361.763742      1.000000
#
#        OperatingSystems       Browser        Region   TrafficType  \
# count      12330.000000  12330.000000  12330.000000  12330.000000
# mean           2.124006      2.357097      3.147364      4.069586
# std            0.911325      1.717277      2.401591      4.025169
# min            1.000000      1.000000      1.000000      1.000000
# 25%            2.000000      2.000000      1.000000      2.000000
# 50%            2.000000      2.000000      3.000000      2.000000
# 75%            3.000000      2.000000      4.000000      4.000000
# max            8.000000     13.000000      9.000000     20.000000
#
#             Weekend       Revenue      MonthNum  VisitorTypeNum
# count  12330.000000  12330.000000  12330.000000    12330.000000
# mean       0.232603      0.154745      7.651987        0.869505
# std        0.422509      0.361676      3.392841        0.356740
# min        0.000000      0.000000      2.000000        0.000000
# 25%        0.000000      0.000000      5.000000        1.000000
# 50%        0.000000      0.000000      7.000000        1.000000
# 75%        0.000000      0.000000     11.000000        1.000000
# max        1.000000      1.000000     12.000000        2.000000

# %% [markdown]
# # 2. Target & Features

# %%
TARGET = "Revenue"
FEATURES = [
    'Administrative',
    'Administrative_Duration',
    'BounceRates',
    'Browser',
    'ExitRates',
    'Informational',
    'Informational_Duration',
    'MonthNum',
    'OperatingSystems',
    'PageValues',
    'ProductRelated',
    'ProductRelated_Duration',
    'Region',
    'SpecialDay',
    'TrafficType',
    'VisitorTypeNum',
    'Weekend'
]

# %%
X = df[FEATURES]
Y = df[TARGET]

# %%
X.shape, Y.shape
# Out:
# ((12330, 17), (12330,))

# %% [markdown]
# # 3. Tree-Based Modeling

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn import metrics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_x, test_x, train_y, test_y= train_test_split(X, Y, test_size=0.2, random_state=1234)

# %%
train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((9864, 17), (2466, 17), (9864,), (2466,))

# %%
train_y.mean(), test_y.mean()
# Out:
# (0.15450121654501217, 0.15571776155717762)

# %%
def eval_func(actual, pred, pred_proba):
    # Accuracy & Precision & Recall
    accuracy = (actual == pred).mean()
    precision = metrics.precision_score(actual, pred)
    recall = metrics.recall_score(actual, pred)
    print("** Key Metrics:")
    print(f"Accuracy: {accuracy*100:.1f}%, Precision: {precision*100:.01f}%, Recall: {recall*100:.01f}%")
    # AUC/ROC
    print("\n\n** AUC/ROC:")
    dp = metrics.RocCurveDisplay.from_predictions(
        actual,
        pred_proba,
        name="Conversion",
        color="darkorange",
    )
    _ = dp.ax_.set(
        xlabel="False Positive Rate",
        ylabel="True Positive Rate",
        title="ROC Curve",
    )
    plt.grid()
    plt.show()
    # Confusion Matrix
    print("\n\n** Confusion Matrix:")
    cf_matrix = metrics.confusion_matrix(actual, pred)
    
    ax = plt.subplot()
    sns.heatmap(
        cf_matrix, 
        annot=True, 
        annot_kws={"size": 10},
        fmt="g", 
        ax=ax
    )

    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")
    ax.set_title(f"Confusion Matrix")
    plt.show()
    
    ax = plt.subplot()
    sns.heatmap(
        cf_matrix/cf_matrix.sum(axis=0), 
        annot=True, 
        annot_kws={"size": 10},
        fmt=".1%", 
        cmap='Blues',
        ax=ax
    )

    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")
    ax.set_title(f"Confusion Matrix - Prediction Precision")
    plt.show()
    
    ax = plt.subplot()
    sns.heatmap(
        cf_matrix/cf_matrix.sum(axis=1)[...,None], 
        annot=True, 
        annot_kws={"size": 10},
        fmt=".1%", 
        cmap='Blues',
        ax=ax
    )

    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")
    ax.set_title(f"Confusion Matrix - Prediction Recall")
    plt.show()

# %% [markdown]
# ## 3.1. RandomForest

# %% [markdown]
# ### 3.1.1. Train

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(
    n_estimators=250, max_depth=5, class_weight="balanced", n_jobs=-1
)

# %%
# %%time

rf_model.fit(train_x, train_y)
# Out:
# CPU times: user 1.52 s, sys: 188 ms, total: 1.7 s
# Wall time: 465 ms
# RandomForestClassifier(class_weight='balanced', max_depth=5, n_estimators=250,
#                        n_jobs=-1)

# %% [markdown]
# ### 3.1.2. Eval

# %%
rf_pred = rf_model.predict(test_x)

# %%
rf_pred_proba = rf_model.predict_proba(test_x)[:,1]

# %%
rf_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
rf_pred_proba
# Out:
# array([0.3974333 , 0.01656874, 0.16027669, ..., 0.79373497, 0.3225237 ,
#        0.29421571])

# %%
fpr, tpr, thresholds = metrics.roc_curve(test_y, rf_pred_proba, pos_label=2)
# Out:
# /Users/yoonhyuph/miniconda3/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(

# %%
eval_func(test_y, rf_pred, rf_pred_proba)
# Out:
# ** Key Metrics:
# Accuracy: 86.2%, Precision: 53.6%, Recall: 84.4%
#
#
# ** AUC/ROC:
# ** Confusion Matrix:

# %% [markdown]
# ## 3.2. XGBoost

# %% [markdown]
# ### 3.2.1. Train

# %%
from xgboost import XGBClassifier

# %%
train_y.mean(), 1/train_y.mean()
# Out:
# (0.15450121654501217, 6.47244094488189)

# %%
xgb_model = XGBClassifier(
    n_estimators=100,
    max_depth=5,
    scale_pos_weight=1/train_y.mean(),
)

# %%
# %%time

xgb_model.fit(train_x, train_y)
# Out:
# CPU times: user 4.31 s, sys: 164 ms, total: 4.47 s
# Wall time: 303 ms
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %% [markdown]
# ### 3.2.2. Eval

# %%
xgb_pred = xgb_model.predict(test_x)

# %%
xgb_pred_proba = xgb_model.predict_proba(test_x)[:,1]

# %%
eval_func(test_y, xgb_pred, xgb_pred_proba)
# Out:
# ** Key Metrics:
# Accuracy: 86.6%, Precision: 54.9%, Recall: 79.2%
#
#
# ** AUC/ROC:
# ** Confusion Matrix:

# %% [markdown]
# # 4. Deep Learning Based Modeling

# %%
import keras
# Out:
# 2024-04-23 16:58:43.571926: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 4.0. Normalize

# %%
mean = train_x.mean()
std = train_x.std()

# %%
normed_train_x = (train_x - mean)/std
normed_test_x = (test_x - mean)/std

# %%
print("** Mean: ")
display(pd.DataFrame(mean))

print("** STD: ")
display(pd.DataFrame(std))
# Out:
# ** Mean:
#                                    0
# Administrative              2.304745
# Administrative_Duration    80.442878
# BounceRates                 0.022473
# Browser                     2.339619
# ExitRates                   0.043376
# Informational               0.500710
# Informational_Duration     35.041119
# MonthNum                    7.636050
# OperatingSystems            2.121857
# PageValues                  5.842192
# ProductRelated             31.715126
# ProductRelated_Duration  1194.410925
# Region                      3.133820
# SpecialDay                  0.061577
# TrafficType                 4.071675
# VisitorTypeNum              0.869728
# Weekend                     0.231042
# ** STD:
#                                    0
# Administrative              3.312479
# Administrative_Duration   175.872996
# BounceRates                 0.048757
# Browser                     1.701199
# ExitRates                   0.048707
# Informational               1.264558
# Informational_Duration    142.434615
# MonthNum                    3.388666
# OperatingSystems            0.916106
# PageValues                 18.774015
# ProductRelated             43.653744
# ProductRelated_Duration  1800.417452
# Region                      2.391589
# SpecialDay                  0.198503
# TrafficType                 4.015739
# VisitorTypeNum              0.356513
# Weekend                     0.421521

# %%
print("** Normed Mean: ")
display(pd.DataFrame(normed_train_x.mean()))

print("** Normed STD: ")
display(pd.DataFrame(normed_train_x.std()))
# Out:
# ** Normed Mean:
#                                     0
# Administrative          -3.889832e-17
# Administrative_Duration -8.644072e-18
# BounceRates             -5.546613e-17
# Browser                  2.953391e-17
# ExitRates               -1.030085e-16
# Informational           -6.194918e-17
# Informational_Duration   2.269069e-17
# MonthNum                -8.860174e-17
# OperatingSystems        -8.500004e-17
# PageValues              -1.584747e-17
# ProductRelated          -1.512713e-17
# ProductRelated_Duration  2.737290e-17
# Region                  -4.970342e-17
# SpecialDay               8.103818e-17
# TrafficType              1.980933e-17
# VisitorTypeNum           4.610172e-17
# Weekend                 -9.652547e-17
# ** Normed STD:
#                            0
# Administrative           1.0
# Administrative_Duration  1.0
# BounceRates              1.0
# Browser                  1.0
# ExitRates                1.0
# Informational            1.0
# Informational_Duration   1.0
# MonthNum                 1.0
# OperatingSystems         1.0
# PageValues               1.0
# ProductRelated           1.0
# ProductRelated_Duration  1.0
# Region                   1.0
# SpecialDay               1.0
# TrafficType              1.0
# VisitorTypeNum           1.0
# Weekend                  1.0

# %% [markdown]
# ## 4.1. Wide Net

# %%
model = keras.Sequential(
    [
        keras.Input(shape=normed_train_x.shape[1:]),
        keras.layers.Dense(2048, activation="relu"),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation="sigmoid"),
    ]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2048)              36864
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 38,913
# Trainable params: 38,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 4.1.1. Train

# %%
model_metrics = [
    keras.metrics.Accuracy(name="accuracy"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
]

model.compile(
    optimizer=keras.optimizers.Adam(0.001), loss="binary_crossentropy", metrics=model_metrics
)

best_model_path = "./checkpoint.wide-model.keras"
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=best_model_path,
    monitor="val_precision",
    mode="max",
    save_best_only=True
)

class_weight = {0: 1, 1: 1/train_y.mean()}

history = model.fit(
    normed_train_x.to_numpy(),
    train_y.to_numpy(),
    batch_size=64,
    epochs=30,
    verbose=2,
    callbacks=[
        model_checkpoint_callback,
    ],
    validation_data=(normed_test_x.to_numpy(), test_y.to_numpy()),
    class_weight=class_weight,
)
# Out:
# Epoch 1/30
# 155/155 - 1s - loss: 0.8283 - accuracy: 8.1103e-04 - precision: 0.3927 - recall: 0.8209 - val_loss: 0.4141 - val_accuracy: 4.0551e-04 - val_precision: 0.4737 - val_recall: 0.7734 - 1s/epoch - 8ms/step
# Epoch 2/30
# 155/155 - 0s - loss: 0.7358 - accuracy: 2.0276e-04 - precision: 0.4643 - recall: 0.8189 - val_loss: 0.4529 - val_accuracy: 0.0000e+00 - val_precision: 0.4411 - val_recall: 0.8490 - 321ms/epoch - 2ms/step
# Epoch 3/30
# 155/155 - 0s - loss: 0.6921 - accuracy: 1.0138e-04 - precision: 0.4644 - recall: 0.8399 - val_loss: 0.3998 - val_accuracy: 0.0000e+00 - val_precision: 0.4871 - val_recall: 0.8359 - 301ms/epoch - 2ms/step
# Epoch 4/30
# 155/155 - 0s - loss: 0.6690 - accuracy: 0.0000e+00 - precision: 0.4812 - recall: 0.8412 - val_loss: 0.4595 - val_accuracy: 0.0000e+00 - val_precision: 0.4221 - val_recall: 0.8672 - 291ms/epoch - 2ms/step
# Epoch 5/30
# 155/155 - 0s - loss: 0.6570 - accuracy: 0.0000e+00 - precision: 0.4811 - recall: 0.8425 - val_loss: 0.4210 - val_accuracy: 0.0000e+00 - val_precision: 0.4707 - val_recall: 0.8568 - 294ms/epoch - 2ms/step
# Epoch 6/30
# 155/155 - 0s - loss: 0.6482 - accuracy: 0.0000e+00 - precision: 0.4884 - recall: 0.8419 - val_loss: 0.4648 - val_accuracy: 0.0000e+00 - val_precision: 0.4177 - val_recall: 0.8854 - 291ms/epoch - 2ms/step
# Epoch 7/30
# 155/155 - 0s - loss: 0.6398 - accuracy: 0.0000e+00 - precision: 0.4920 - recall: 0.8491 - val_loss: 0.4572 - val_accuracy: 0.0000e+00 - val_precision: 0.4130 - val_recall: 0.8776 - 290ms/epoch - 2ms/step
# Epoch 8/30
# 155/155 - 0s - loss: 0.6311 - accuracy: 0.0000e+00 - precision: 0.4871 - recall: 0.8563 - val_loss: 0.3891 - val_accuracy: 0.0000e+00 - val_precision: 0.4931 - val_recall: 0.8411 - 303ms/epoch - 2ms/step
# Epoch 9/30
# 155/155 - 0s - loss: 0.6410 - accuracy: 0.0000e+00 - precision: 0.4826 - recall: 0.8451 - val_loss: 0.3947 - val_accuracy: 0.0000e+00 - val_precision: 0.4932 - val_recall: 0.8516 - 330ms/epoch - 2ms/step
# Epoch 10/30
# 155/155 - 0s - loss: 0.6298 - accuracy: 0.0000e+00 - precision: 0.4917 - recall: 0.8576 - val_loss: 0.4761 - val_accuracy: 0.0000e+00 - val_precision: 0.4298 - val_recall: 0.9010 - 307ms/epoch - 2ms/step
# Epoch 11/30
# 155/155 - 0s - loss: 0.6225 - accuracy: 0.0000e+00 - precision: 0.4827 - recall: 0.8622 - val_loss: 0.4686 - val_accuracy: 0.0000e+00 - val_precision: 0.4321 - val_recall: 0.8776 - 298ms/epoch - 2ms/step
# Epoch 12/30
# 155/155 - 0s - loss: 0.6184 - accuracy: 0.0000e+00 - precision: 0.4878 - recall: 0.8648 - val_loss: 0.4665 - val_accuracy: 0.0000e+00 - val_precision: 0.4130 - val_recall: 0.8906 - 299ms/epoch - 2ms/step
# Epoch 13/30
# 155/155 - 0s - loss: 0.6094 - accuracy: 0.0000e+00 - precision: 0.4977 - recall: 0.8602 - val_loss: 0.4604 - val_accuracy: 0.0000e+00 - val_precision: 0.4306 - val_recall: 0.8802 - 296ms/epoch - 2ms/step
# Epoch 14/30
# 155/155 - 0s - loss: 0.6072 - accuracy: 0.0000e+00 - precision: 0.4946 - recall: 0.8675 - val_loss: 0.3943 - val_accuracy: 0.0000e+00 - val_precision: 0.5031 - val_recall: 0.8490 - 320ms/epoch - 2ms/step
# Epoch 15/30
# 155/155 - 0s - loss: 0.5979 - accuracy: 0.0000e+00 - precision: 0.5038 - recall: 0.8688 - val_loss: 0.3517 - val_accuracy: 0.0000e+00 - val_precision: 0.5246 - val_recall: 0.8333 - 345ms/epoch - 2ms/step
# Epoch 16/30
# 155/155 - 0s - loss: 0.5987 - accuracy: 0.0000e+00 - precision: 0.5073 - recall: 0.8694 - val_loss: 0.4149 - val_accuracy: 0.0000e+00 - val_precision: 0.4397 - val_recall: 0.8542 - 299ms/epoch - 2ms/step
# Epoch 17/30
# 155/155 - 0s - loss: 0.5921 - accuracy: 0.0000e+00 - precision: 0.4968 - recall: 0.8720 - val_loss: 0.4560 - val_accuracy: 0.0000e+00 - val_precision: 0.4286 - val_recall: 0.8828 - 343ms/epoch - 2ms/step
# Epoch 18/30
# 155/155 - 0s - loss: 0.5887 - accuracy: 0.0000e+00 - precision: 0.4987 - recall: 0.8681 - val_loss: 0.4385 - val_accuracy: 0.0000e+00 - val_precision: 0.4712 - val_recall: 0.8516 - 442ms/epoch - 3ms/step
# Epoch 19/30
# 155/155 - 0s - loss: 0.5847 - accuracy: 0.0000e+00 - precision: 0.5074 - recall: 0.8740 - val_loss: 0.4147 - val_accuracy: 0.0000e+00 - val_precision: 0.4601 - val_recall: 0.8568 - 428ms/epoch - 3ms/step
# Epoch 20/30
# 155/155 - 0s - loss: 0.5719 - accuracy: 0.0000e+00 - precision: 0.5108 - recall: 0.8806 - val_loss: 0.3729 - val_accuracy: 0.0000e+00 - val_precision: 0.4985 - val_recall: 0.8385 - 298ms/epoch - 2ms/step
# Epoch 21/30
# 155/155 - 0s - loss: 0.5699 - accuracy: 0.0000e+00 - precision: 0.5196 - recall: 0.8799 - val_loss: 0.4014 - val_accuracy: 0.0000e+00 - val_precision: 0.4732 - val_recall: 0.8516 - 357ms/epoch - 2ms/step
# Epoch 22/30
# 155/155 - 0s - loss: 0.5687 - accuracy: 0.0000e+00 - precision: 0.5158 - recall: 0.8780 - val_loss: 0.4511 - val_accuracy: 0.0000e+00 - val_precision: 0.4466 - val_recall: 0.8828 - 338ms/epoch - 2ms/step
# Epoch 23/30
# 155/155 - 0s - loss: 0.5652 - accuracy: 0.0000e+00 - precision: 0.5081 - recall: 0.8806 - val_loss: 0.3877 - val_accuracy: 0.0000e+00 - val_precision: 0.4933 - val_recall: 0.8568 - 333ms/epoch - 2ms/step
# Epoch 24/30
# 155/155 - 0s - loss: 0.5563 - accuracy: 0.0000e+00 - precision: 0.5172 - recall: 0.8871 - val_loss: 0.4214 - val_accuracy: 0.0000e+00 - val_precision: 0.4764 - val_recall: 0.8672 - 310ms/epoch - 2ms/step
# Epoch 25/30
# 155/155 - 0s - loss: 0.5511 - accuracy: 0.0000e+00 - precision: 0.5237 - recall: 0.8983 - val_loss: 0.3775 - val_accuracy: 0.0000e+00 - val_precision: 0.4938 - val_recall: 0.8307 - 336ms/epoch - 2ms/step
# Epoch 26/30
# 155/155 - 0s - loss: 0.5512 - accuracy: 0.0000e+00 - precision: 0.5142 - recall: 0.8891 - val_loss: 0.3656 - val_accuracy: 0.0000e+00 - val_precision: 0.4976 - val_recall: 0.8255 - 345ms/epoch - 2ms/step
# Epoch 27/30
# 155/155 - 0s - loss: 0.5389 - accuracy: 0.0000e+00 - precision: 0.5222 - recall: 0.8937 - val_loss: 0.4488 - val_accuracy: 0.0000e+00 - val_precision: 0.4390 - val_recall: 0.8906 - 327ms/epoch - 2ms/step
# Epoch 28/30
# 155/155 - 0s - loss: 0.5344 - accuracy: 0.0000e+00 - precision: 0.5258 - recall: 0.8898 - val_loss: 0.4331 - val_accuracy: 0.0000e+00 - val_precision: 0.4430 - val_recall: 0.8802 - 310ms/epoch - 2ms/step
# Epoch 29/30
# 155/155 - 0s - loss: 0.5442 - accuracy: 0.0000e+00 - precision: 0.5123 - recall: 0.8917 - val_loss: 0.4322 - val_accuracy: 0.0000e+00 - val_precision: 0.4538 - val_recall: 0.8438 - 320ms/epoch - 2ms/step
# Epoch 30/30
# 155/155 - 0s - loss: 0.5381 - accuracy: 0.0000e+00 - precision: 0.5087 - recall: 0.9022 - val_loss: 0.3741 - val_accuracy: 0.0000e+00 - val_precision: 0.4961 - val_recall: 0.8307 - 306ms/epoch - 2ms/step

# %%
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# ### 4.1.2. Eval

# %%
wide_best_model = keras.models.load_model(best_model_path)

# %%
wide_best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2048)              36864
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 38,913
# Trainable params: 38,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
unflattened = wide_best_model.predict(normed_test_x)
# Out:
# 78/78 [==============================] - 0s 634us/step

# %%
unflattened
# Out:
# array([[4.1800496e-01],
#        [1.5303074e-06],
#        [2.6588384e-03],
#        ...,
#        [9.3577254e-01],
#        [2.1845967e-01],
#        [7.7146672e-02]], dtype=float32)

# %%
wide_pred_proba = wide_best_model.predict(normed_test_x).flatten()
# Out:
# 78/78 [==============================] - 0s 634us/step

# %%
wide_pred_proba
# Out:
# array([4.1800496e-01, 1.5303074e-06, 2.6588384e-03, ..., 9.3577254e-01,
#        2.1845967e-01, 7.7146672e-02], dtype=float32)

# %%
wide_preds = [1 if x > 0.5 else 0 for x in wide_pred_proba]

# %%
eval_func(test_y, wide_preds, wide_pred_proba)
# Out:
# ** Key Metrics:
# Accuracy: 85.6%, Precision: 52.5%, Recall: 83.3%
#
#
# ** AUC/ROC:
# ** Confusion Matrix:

# %% [markdown]
# ## 4.2. Deep Net

# %%
model = keras.Sequential(
    [
        keras.Input(shape=normed_train_x.shape[1:]),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation="sigmoid"),
    ]
)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 128)               2304
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 35,457
# Trainable params: 35,457
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 4.2.1. Train

# %%
model_metrics = [
    keras.metrics.Accuracy(name="accuracy"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
]

model.compile(
    optimizer=keras.optimizers.Adam(0.001), loss="binary_crossentropy", metrics=model_metrics
)

best_model_path = "./checkpoint.deep-model.keras"

early_stopping_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=0.001,
    patience=3
)
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=best_model_path,
    monitor="val_precision",
    mode="max",
    save_best_only=True
)

class_weight = {0: 1, 1: 1/train_y.mean()}

history = model.fit(
    normed_train_x.to_numpy(),
    train_y.to_numpy(),
    batch_size=64,
    epochs=30,
    verbose=2,
    callbacks=[
        # early_stopping_callback, 
        model_checkpoint_callback,
    ],
    validation_data=(normed_test_x.to_numpy(), test_y.to_numpy()),
    class_weight=class_weight,
)
# Out:
# Epoch 1/30
# 155/155 - 1s - loss: 0.8585 - accuracy: 4.0551e-04 - precision: 0.3863 - recall: 0.8051 - val_loss: 0.4760 - val_accuracy: 8.1103e-04 - val_precision: 0.4198 - val_recall: 0.8516 - 1s/epoch - 7ms/step
# Epoch 2/30
# 155/155 - 0s - loss: 0.7429 - accuracy: 3.0414e-04 - precision: 0.4285 - recall: 0.8419 - val_loss: 0.4361 - val_accuracy: 0.0000e+00 - val_precision: 0.4369 - val_recall: 0.8568 - 268ms/epoch - 2ms/step
# Epoch 3/30
# 155/155 - 0s - loss: 0.6960 - accuracy: 1.0138e-04 - precision: 0.4556 - recall: 0.8386 - val_loss: 0.4127 - val_accuracy: 0.0000e+00 - val_precision: 0.4425 - val_recall: 0.8620 - 277ms/epoch - 2ms/step
# Epoch 4/30
# 155/155 - 0s - loss: 0.6672 - accuracy: 1.0138e-04 - precision: 0.4564 - recall: 0.8543 - val_loss: 0.4452 - val_accuracy: 0.0000e+00 - val_precision: 0.4615 - val_recall: 0.8594 - 297ms/epoch - 2ms/step
# Epoch 5/30
# 155/155 - 0s - loss: 0.6504 - accuracy: 0.0000e+00 - precision: 0.4751 - recall: 0.8570 - val_loss: 0.3956 - val_accuracy: 0.0000e+00 - val_precision: 0.4444 - val_recall: 0.8646 - 241ms/epoch - 2ms/step
# Epoch 6/30
# 155/155 - 0s - loss: 0.6288 - accuracy: 1.0138e-04 - precision: 0.4805 - recall: 0.8648 - val_loss: 0.4112 - val_accuracy: 0.0000e+00 - val_precision: 0.4337 - val_recall: 0.8776 - 248ms/epoch - 2ms/step
# Epoch 7/30
# 155/155 - 0s - loss: 0.6167 - accuracy: 0.0000e+00 - precision: 0.4791 - recall: 0.8720 - val_loss: 0.3662 - val_accuracy: 0.0000e+00 - val_precision: 0.4908 - val_recall: 0.8307 - 273ms/epoch - 2ms/step
# Epoch 8/30
# 155/155 - 0s - loss: 0.6206 - accuracy: 1.0138e-04 - precision: 0.4809 - recall: 0.8747 - val_loss: 0.4429 - val_accuracy: 0.0000e+00 - val_precision: 0.4237 - val_recall: 0.9036 - 241ms/epoch - 2ms/step
# Epoch 9/30
# 155/155 - 0s - loss: 0.6077 - accuracy: 0.0000e+00 - precision: 0.4670 - recall: 0.8812 - val_loss: 0.4128 - val_accuracy: 0.0000e+00 - val_precision: 0.4955 - val_recall: 0.8542 - 263ms/epoch - 2ms/step
# Epoch 10/30
# 155/155 - 0s - loss: 0.5816 - accuracy: 0.0000e+00 - precision: 0.4820 - recall: 0.8944 - val_loss: 0.3562 - val_accuracy: 0.0000e+00 - val_precision: 0.5047 - val_recall: 0.8438 - 291ms/epoch - 2ms/step
# Epoch 11/30
# 155/155 - 0s - loss: 0.5788 - accuracy: 0.0000e+00 - precision: 0.4875 - recall: 0.8957 - val_loss: 0.3922 - val_accuracy: 0.0000e+00 - val_precision: 0.4568 - val_recall: 0.8802 - 246ms/epoch - 2ms/step
# Epoch 12/30
# 155/155 - 0s - loss: 0.5726 - accuracy: 0.0000e+00 - precision: 0.4844 - recall: 0.8950 - val_loss: 0.4189 - val_accuracy: 0.0000e+00 - val_precision: 0.4348 - val_recall: 0.8776 - 241ms/epoch - 2ms/step
# Epoch 13/30
# 155/155 - 0s - loss: 0.5539 - accuracy: 0.0000e+00 - precision: 0.4995 - recall: 0.9055 - val_loss: 0.4064 - val_accuracy: 0.0000e+00 - val_precision: 0.4512 - val_recall: 0.8672 - 242ms/epoch - 2ms/step
# Epoch 14/30
# 155/155 - 0s - loss: 0.5569 - accuracy: 0.0000e+00 - precision: 0.4826 - recall: 0.9101 - val_loss: 0.3709 - val_accuracy: 0.0000e+00 - val_precision: 0.4887 - val_recall: 0.8464 - 254ms/epoch - 2ms/step
# Epoch 15/30
# 155/155 - 0s - loss: 0.5469 - accuracy: 0.0000e+00 - precision: 0.4924 - recall: 0.9081 - val_loss: 0.3763 - val_accuracy: 0.0000e+00 - val_precision: 0.4703 - val_recall: 0.8464 - 248ms/epoch - 2ms/step
# Epoch 16/30
# 155/155 - 0s - loss: 0.5372 - accuracy: 0.0000e+00 - precision: 0.5022 - recall: 0.9114 - val_loss: 0.3973 - val_accuracy: 0.0000e+00 - val_precision: 0.4523 - val_recall: 0.8646 - 243ms/epoch - 2ms/step
# Epoch 17/30
# 155/155 - 0s - loss: 0.5279 - accuracy: 0.0000e+00 - precision: 0.4975 - recall: 0.9193 - val_loss: 0.3266 - val_accuracy: 0.0000e+00 - val_precision: 0.5281 - val_recall: 0.8073 - 264ms/epoch - 2ms/step
# Epoch 18/30
# 155/155 - 0s - loss: 0.5241 - accuracy: 0.0000e+00 - precision: 0.5002 - recall: 0.9154 - val_loss: 0.3474 - val_accuracy: 0.0000e+00 - val_precision: 0.5055 - val_recall: 0.8385 - 249ms/epoch - 2ms/step
# Epoch 19/30
# 155/155 - 0s - loss: 0.5178 - accuracy: 0.0000e+00 - precision: 0.5053 - recall: 0.9154 - val_loss: 0.4002 - val_accuracy: 0.0000e+00 - val_precision: 0.4549 - val_recall: 0.8542 - 241ms/epoch - 2ms/step
# Epoch 20/30
# 155/155 - 0s - loss: 0.4941 - accuracy: 0.0000e+00 - precision: 0.5168 - recall: 0.9265 - val_loss: 0.4039 - val_accuracy: 0.0000e+00 - val_precision: 0.4368 - val_recall: 0.8724 - 241ms/epoch - 2ms/step
# Epoch 21/30
# 155/155 - 0s - loss: 0.4980 - accuracy: 0.0000e+00 - precision: 0.5052 - recall: 0.9331 - val_loss: 0.3785 - val_accuracy: 0.0000e+00 - val_precision: 0.4696 - val_recall: 0.8438 - 251ms/epoch - 2ms/step
# Epoch 22/30
# 155/155 - 0s - loss: 0.4897 - accuracy: 0.0000e+00 - precision: 0.5111 - recall: 0.9370 - val_loss: 0.3978 - val_accuracy: 0.0000e+00 - val_precision: 0.4460 - val_recall: 0.8490 - 247ms/epoch - 2ms/step
# Epoch 23/30
# 155/155 - 0s - loss: 0.4816 - accuracy: 0.0000e+00 - precision: 0.5153 - recall: 0.9311 - val_loss: 0.3774 - val_accuracy: 0.0000e+00 - val_precision: 0.4730 - val_recall: 0.8438 - 249ms/epoch - 2ms/step
# Epoch 24/30
# 155/155 - 0s - loss: 0.4694 - accuracy: 0.0000e+00 - precision: 0.5107 - recall: 0.9364 - val_loss: 0.3584 - val_accuracy: 0.0000e+00 - val_precision: 0.4878 - val_recall: 0.8359 - 251ms/epoch - 2ms/step
# Epoch 25/30
# 155/155 - 0s - loss: 0.4613 - accuracy: 0.0000e+00 - precision: 0.5236 - recall: 0.9318 - val_loss: 0.3824 - val_accuracy: 0.0000e+00 - val_precision: 0.4822 - val_recall: 0.8464 - 267ms/epoch - 2ms/step
# Epoch 26/30
# 155/155 - 0s - loss: 0.4518 - accuracy: 0.0000e+00 - precision: 0.5223 - recall: 0.9449 - val_loss: 0.3884 - val_accuracy: 4.0551e-04 - val_precision: 0.4931 - val_recall: 0.8333 - 251ms/epoch - 2ms/step
# Epoch 27/30
# 155/155 - 0s - loss: 0.4504 - accuracy: 0.0000e+00 - precision: 0.5305 - recall: 0.9364 - val_loss: 0.4278 - val_accuracy: 0.0000e+00 - val_precision: 0.4463 - val_recall: 0.8542 - 246ms/epoch - 2ms/step
# Epoch 28/30
# 155/155 - 0s - loss: 0.4390 - accuracy: 0.0000e+00 - precision: 0.5327 - recall: 0.9462 - val_loss: 0.4093 - val_accuracy: 4.0551e-04 - val_precision: 0.4894 - val_recall: 0.8385 - 247ms/epoch - 2ms/step
# Epoch 29/30
# 155/155 - 0s - loss: 0.4326 - accuracy: 0.0000e+00 - precision: 0.5361 - recall: 0.9409 - val_loss: 0.3848 - val_accuracy: 4.0551e-04 - val_precision: 0.4901 - val_recall: 0.8385 - 252ms/epoch - 2ms/step
# Epoch 30/30
# 155/155 - 0s - loss: 0.4352 - accuracy: 0.0000e+00 - precision: 0.5298 - recall: 0.9442 - val_loss: 0.3997 - val_accuracy: 4.0551e-04 - val_precision: 0.4985 - val_recall: 0.8385 - 250ms/epoch - 2ms/step

# %%
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# ### 4.1.2. Eval

# %%
deep_best_model = keras.models.load_model(best_model_path)

# %%
deep_best_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 128)               2304
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 35,457
# Trainable params: 35,457
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_pred_proba = deep_best_model.predict(normed_test_x).flatten()
# Out:
# 78/78 [==============================] - 0s 610us/step

# %%
deep_preds = [1 if x > 0.5 else 0 for x in deep_pred_proba]

# %%
eval_func(test_y, deep_preds, deep_pred_proba)
# Out:
# ** Key Metrics:
# Accuracy: 85.8%, Precision: 52.8%, Recall: 80.7%
#
#
# ** AUC/ROC:
# ** Confusion Matrix:

# %% [markdown]
# # 5. A/B Testing

# %%
test_y.shape
# Out:
# (2466,)

# %% [markdown]
# ## 5.1. Random Selection of Test Groups

# %%
group_a_indexes = sorted(list(np.random.choice(2000, 1000, replace=False)))
group_b_indexes = [x for x in range(2000) if x not in group_a_indexes]

# %%
len(group_a_indexes)
# Out:
# 1000

# %%
np.min(group_a_indexes), np.max(group_a_indexes)
# Out:
# (0, 1999)

# %%
len(group_b_indexes)
# Out:
# 1000

# %%
np.min(group_b_indexes), np.max(group_b_indexes)
# Out:
# (1, 1997)

# %% [markdown]
# ## 5.2. XGBoost vs. Wide Net A/B Testing Simulation

# %%
from tqdm import tqdm

# %%
group_a_actuals = test_y.iloc[group_a_indexes].to_numpy()
group_b_actuals = test_y.iloc[group_b_indexes].to_numpy()

group_a_preds = []
group_b_preds = []

for customer in tqdm(range(2000)):
    if customer in group_a_indexes:
        # route to XGBoost
        conversion = test_y.iloc[customer]
        pred_prob = xgb_model.predict_proba(
            np.array([test_x.iloc[customer].to_numpy(),])
        )[0][1]
        pred = 1 if pred_prob > 0.5 else 0
        group_a_preds.append(pred)
    elif customer in group_b_indexes:
        # route to Wide Net
        conversion = test_y.iloc[customer]
        pred_prob = wide_best_model.predict(
            np.array([normed_test_x.iloc[customer].to_numpy(),]), verbose=0
        )[0][0]
        pred = 1 if pred_prob > 0.5 else 0
        group_b_preds.append(pred)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:55<00:00, 35.96it/s]

# %%
np.sum(group_a_preds), np.sum(group_a_actuals)
# Out:
# (233, 149)

# %%
def get_cumulative_metrics(actuals, preds):
    cum_conversions = []
    missed_opportunities = []
    
    customer_counter = 0
    cum_conversion_count = 0
    missed_opp_count = 0
    for actual, pred in zip(actuals, preds):
        customer_counter += 1
        if pred == 1:
            if actual == 1:
                cum_conversion_count += 1
        else:
            if actual == 1:
                missed_opp_count += 1
        cum_conversions.append(cum_conversion_count/customer_counter)
        missed_opportunities.append(missed_opp_count/customer_counter)
    return cum_conversions, missed_opportunities

# %%
a_cum_conv_rates, a_missed_opp_rates = get_cumulative_metrics(group_a_actuals, group_a_preds)
b_cum_conv_rates, b_missed_opp_rates = get_cumulative_metrics(group_b_actuals, group_b_preds)

# %%
ab_results_df = pd.DataFrame({
    "group_a_cum_conversion_rate": a_cum_conv_rates, 
    "group_a_cum_missed_opportunity_rate": a_missed_opp_rates,
    "group_b_cum_conversion_rate": b_cum_conv_rates, 
    "group_b_cum_missed_opportunity_rate": b_missed_opp_rates,
})

# %%
ax = (
    ab_results_df[[
        "group_a_cum_conversion_rate", "group_b_cum_conversion_rate"
    ]]*100
).plot(
    figsize=(8, 5),
    grid=True
)

ax.set_ylabel("Conversion Rate (%)")
ax.set_xlabel("Customer Count")
ax.set_title("Cumulative Conversion Rates over Time (A: XGBoost, B: Wide Net)")
plt.show()

# %%
ax = (
    ab_results_df[[
        "group_a_cum_missed_opportunity_rate", "group_b_cum_missed_opportunity_rate"
    ]]*100
).plot(
    figsize=(8, 5),
    grid=True
)

ax.set_ylabel("Missed Opportunity Rate (%)")
ax.set_xlabel("Customer Count")
ax.set_title("Cumulative Missed Opportunity Rates over Time (A: XGBoost, B: Wide Net)")
plt.show()

# %% [markdown]
# ## 5.3. Significance Test

# %% [markdown]
# ### 5.3.1. Testing Cumulative Distribution --> Wide Net Wins

# %%
from scipy.stats import ttest_ind

# %%
# Performing the t-test
t, p = ttest_ind(a_cum_conv_rates, b_cum_conv_rates)
print(f"Conversion Rate Difference Significance -- t: {t:.3f} & p: {p:.3f}")
t, p = ttest_ind(a_missed_opp_rates, b_missed_opp_rates)
print(f"Missed Opportunity Rate Difference Significance -- t: {t:.3f} & p: {p:.3f}")
# Out:
# Conversion Rate Difference Significance -- t: 13.553 & p: 0.000
# Missed Opportunity Rate Difference Significance -- t: -1.561 & p: 0.119

# %% [markdown]
# ### 5.3.2. Testing Mean

# %%
from scipy.stats import t as tstat

# %% [markdown]
# #### Conversion Rate Test --> Wide Net Wins
#
# Wide Net has significantly higher conversion rate

# %%
a_conv_rate = a_cum_conv_rates[-1]
b_conv_rate = b_cum_conv_rates[-1]

a_conv_rate, b_conv_rate
# Out:
# (0.123, 0.123)

# %%
sample_size = 1000

a_mean = a_conv_rate * sample_size
b_mean = b_conv_rate * sample_size

a_std = np.sqrt(sample_size*a_conv_rate*(1-a_conv_rate))
b_std = np.sqrt(sample_size*b_conv_rate*(1-b_conv_rate))

a_mean, a_std, b_mean, b_std
# Out:
# (123.0, 10.386096475577338, 123.0, 10.386096475577338)

# %%
t_score = (a_mean - b_mean)/np.sqrt( (a_std**2)/sample_size + (b_std**2)/sample_size )
t_score
# Out:
# 0.0

# %%
pvalue = tstat.sf(np.abs(t_score), sample_size-1) * 2
print(f"p-value: {pvalue:.03f}")
# Out:
# p-value: 1.000

# %% [markdown]
# #### Missed Opportunity Rate Test --> Wide Net Wins
#
# Wide Net has significantly lower missed opportunity rate

# %%
a_missed_opp_rate = a_missed_opp_rates[-1]
b_missed_opp_rate = b_missed_opp_rates[-1]

a_missed_opp_rate, b_missed_opp_rate
# Out:
# (0.026, 0.032)

# %%
sample_size = 1000

a_mean = a_missed_opp_rate * sample_size
b_mean = b_missed_opp_rate * sample_size

a_std = np.sqrt(sample_size*a_conv_rate*(1-a_conv_rate))
b_std = np.sqrt(sample_size*b_conv_rate*(1-b_conv_rate))

a_mean, a_std, b_mean, b_std
# Out:
# (26.0, 10.386096475577338, 32.0, 10.386096475577338)

# %%
t_score = (a_mean - b_mean)/np.sqrt( (a_std**2)/sample_size + (b_std**2)/sample_size )
t_score
# Out:
# -12.91766150694547

# %%
pvalue = tstat.sf(np.abs(t_score), sample_size-1) * 2
print(f"p-value: {pvalue:.03f}")
# Out:
# p-value: 0.000
